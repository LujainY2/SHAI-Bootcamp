# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # About Features
#
# 1. **Employee ID**: A unique identifier for each employee. Usually a numeric or alphanumeric code.
#
# 2. **Name**: The full name of the employee. This might be split into first and last names in some datasets.
#
# 3. **Department**: The department or division within the organization where the employee works.
#
# 4. **Job Title**: The official title or position held by the employee in the organization.
#
# 5. **Salary**: The amount of money the employee earns. This could be represented as an annual salary, hourly wage, or monthly pay.
#
# 6. **Hire Date**: The date when the employee started working at the organization. Useful for calculating tenure or experience.
#
# 7. **Gender**: The gender of the employee. This might be included in some datasets for diversity and equality analysis.
#
# 8. **Years of Experience**: The total number of years the employee has worked in their field or profession.
#
# 9. **Education Level**: The highest level of education attained by the employee, such as a high school diploma, bachelor's degree, etc.
#
# 10. **Performance Rating**: If available, this could be a measure of the employee's performance in their role, often based on annual review scores.
#
# 11. **Location**: The geographical location or office where the employee works, if the organization has multiple locations.

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('Salary_Data.csv')
#df = pd.read_csv('/content/Salaries.csv')
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# Pattern list
pattern_list = ['HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing']

# Number of elements you want in the new list
num_elements = 6704

# Create the new list by repeating the pattern using list comprehension
result_list = [pattern_list[i % len(pattern_list)] for i in range(num_elements)]

# Print or use the result_list as needed
print(result_list)
# Out:
# ['HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Finance', 'Marketing', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'HR', 'IT', 'Financ
# ...

# %%
df['Department']=result_list

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary Department
# 0                     5.0   90000.0         HR
# 1                     3.0   65000.0         IT
# 2                    15.0  150000.0    Finance
# ...

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df['Education Level'] = df['Education Level'].replace({'phD': 'PhD'})
df['Education Level'] = df['Education Level'].replace({"Bachelor's Degree": "Bachelor's"})
df['Education Level'] = df['Education Level'].replace({"Master's Degree": "Master's"})
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', 'High School'], dtype=object)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary', 'Department'],
#       dtype='object')

# %% [markdown]
# #Basic Data Exploration: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.

# %%
df.shape #number of rows and columns
# Out:
# (6704, 7)

# %%
df.shape[0] #number of rows
# Out:
# 6704

# %%
df.shape[1] #number of columns
# Out:
# 7

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# Department              object
# dtype: object

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# Department             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6704 non-null   float64
#  1   Gender               6704 non-null   object
#  2   Education Level      6704 non-null   object
#  3   Job Title            6704 non-null   object
#  4   Years of Experience  6704 non-null   float64
#  5   Salary               6704 non-null   float64
#  6   Department           6704 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 366.8+ KB

# %% [markdown]
# Descriptive Statistics: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6704.000000          6704.000000    6704.000000
# mean     33.620376             8.094197  115326.720913
# std       7.613548             6.057691   52766.493471
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %% [markdown]
# Data Cleaning: Handle missing data by suitable method with explain why you use it.

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)  #we fill missing values in age and yoe cols with the median val
df['Years of Experience'].fillna(df['Years of Experience'].median(), inplace=True) #also median cuz its the middle val for numric cols

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True) #we fill these cols with the most frequent val
df['Job Title'].fillna(df['Job Title'].mode()[0], inplace=True)

# %%
df['Education Level'].fillna(df['Education Level'].mode()[0], inplace=True)

# %%
df['Salary'].fillna(df['Salary'].median(), inplace=True)   #also median cuz its the middle val for numric cols

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# Department             0
# dtype: int64

# %% [markdown]
# #Basic Data Visualization: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
sns.histplot(data=df,x='Salary')
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
# Count the number of employees in each department
department_counts = df['Department'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %% [markdown]
# Grouped Analysis: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.

# %%
department_group=df.groupby('Department')['Salary'].mean().reset_index()

# %%
education_level_group=df.groupby('Education Level')['Salary'].mean().reset_index()

# %%
years_of_experience_group=df.groupby('Years of Experience')['Salary'].mean().reset_index()

# %%
Age_group=df.groupby('Age')['Salary'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=department_group, x='Department', y='Salary', palette="viridis")
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.title('Average Salary Across Departments')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=education_level_group, x='Education Level', y='Salary', palette="viridis")
plt.xlabel('Education level')
plt.ylabel('Average Salary')
plt.title('Average Salary Across Education levels')
plt.show()

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=years_of_experience_group, x='Years of Experience', y='Salary', palette="viridis")
plt.xlabel('Years of Experience')
plt.ylabel('Average Salary')
plt.title('Average Salary Across Years of Experience ')
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot(data=Age_group, x='Age', y='Salary', palette="viridis")
plt.xlabel('Age')
plt.ylabel('Average Salary')
plt.title('Average Salary Across Ages')
plt.show()

# %% [markdown]
# #Simple Correlation Analysis: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.

# %%
correlation = df['Salary'].corr(df['Years of Experience'])
print(f"Correlation between Salary and Years of Experience: {correlation}")

# Plotting a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Years of Experience', y='Salary', color='blue')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Scatter Plot: Salary vs Years of Experience')
plt.show()
# Out:
# Correlation between Salary and Years of Experience: 0.8089566226529057

# %% [markdown]
# Summary of Insights: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# - all departments has the same avg of salary
# - PhD level of education has the heighest avg salary then Masters then bacholorias then heigh school
# - as yrs of expieriance increase salary increase and age
# - Correlation between Salary and Years of Experience: 0.8089566226529057 which is strong positive correlation
